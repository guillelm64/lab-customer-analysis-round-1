# %%
#Read the three files into python as dataframes
import pandas as pd
import numpy as np
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

df1 = pd.DataFrame(file1)
df2 = pd.DataFrame(file2)
df3 = pd.DataFrame(file3)

# %%
#Dataframes shape

df1.shape
df2.shape
df3.shape
# Out:
# (7070, 11)

# %%
#Standardize header names
def make_lower(df):
    columns = df.columns
    col = []
    for colum in df.columns:
        col.append(colum.lower())
    return col
df1.columns = make_lower(df1)
df2.columns = make_lower(df2)
df3.columns = make_lower(df3)

display(df3)
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
#Rearrange the columns in the dataframe as needed
def rearr(df):
    df = df.reset_index(drop = True)
    return df
rearr(df1)
rearr(df2)
rearr(df3)
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
#Concatenate the three dataframes
df_all = pd.concat([df1,df2,df3], axis = 0)
display(df_all.head(15))
# Out:
#    customer          st gender             education customer lifetime value  \
# 0   RB50392  Washington    NaN                Master                     NaN
# 1   QZ44356     Arizona      F              Bachelor              697953.59%
# 2   AI49188      Nevada      F              Bachelor             1288743.17%
# 3   WW63253  California      M              Bachelor              764586.18%
# 4   GA49547  Washington      M  High School or Below              536307.65%
# 5   OC83172      Oregon      F              Bachelor              825629.78%
# 6   XZ87318      Oregon      F               College              538089.86%
# 7   CF85061     Arizona      M                Master              721610.03%
# 8   DY87989      Oregon      M              Bachelor             2412750.40%
# 9   BQ94931      Oregon      F               College              738817.81%
# 10  SX51350  California      M               College              473899.20%
# ...

# %%
#Which columns are numerical? 
#Which columns are categorical?
num = df_all.select_dtypes(include = ["int16", "int32", "int64", "float16", "float32", "float64"])
display(num.head())
obj = df_all.select_dtypes(include = ['object'])
display(obj.head())
# Out:
#     income  monthly premium auto  total claim amount
# 0      0.0                1000.0            2.704934
# 1      0.0                  94.0         1131.464935
# 2  48767.0                 108.0          566.472247
# 3      0.0                 106.0          529.881344
# 4  36357.0                  68.0           17.269323
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#   number of open complaints     policy type  vehicle class state
# 0                    1/0/00   Personal Auto  Four-Door Car   NaN
# ...

# %%
#Understand the meaning of all columns

# %%
#Perform the data cleaning operations mentioned so far in class

#Delete the column education and the number of open complaints from the dataframe
df_all.drop(['education', 'number of open complaints'], axis = 1)

# %%
#Correct the values in the column customer lifetime value...
#...They are given as a percent, so multiply them by 100 and change dtype to numerical type.
df_all['customer lifetime value'].

# %%
#Check for duplicate rows in the data and remove if any.
df_all2 = df_all.copy()
df_all2 = df_all2.drop_duplicates()
display(df_all2)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#Filter out the data for customers who have an income of 0 or less
df_all2[df_all2['income']<=0]
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 7     CF85061     Arizona      M                Master
# 10    SX51350  California      M               College
# ...       ...         ...    ...                   ...
# 7059  WZ45103         NaN      F              Bachelor
# 7061  RX91025         NaN      M  High School or Below
# 7062  AC13887         NaN      M              Bachelor
# 7067  TD14365         NaN      M              Bachelor
# 7069  Y167826         NaN      M               College
#
#      customer lifetime value  income  monthly premium auto  \
# 0                        NaN     0.0                1000.0
# 1                 697953.59%     0.0                  94.0
# 3                 764586.18%     0.0                 106.0
# 7                 721610.03%     0.0                 101.0
# ...
